# %% [markdown]
# # Selenium

# %% [markdown]
# ## Site do Google
#
# - já estou com o módulo selenium instalado (conda install -c conda forge selenium)
# - já baixei o driver com a versão do meu navegador Firefox(https://github.com/mozilla/geckodriver/releases) ou Chrome (https://chromedriver.chromium.org/downloads)
# - Extraí o arquivo e coloquei na pasta (onde eu sei o caminho)
# - Executei e deixei aberto o driver
#
# - Instalei a extensão Selenium IDE de acordo com o navegadorFirefox (https://addons.mozilla.org/en-US/firefox/addon/selenium-ide/) ou Chrome (https://chrome.google.com/webstore/detail/selenium-ide/mooikfkahbdckldjjndioackbalphokd?hl=en)
#
#
# - Abri o Selenium IDE, criei o projeto e comecei a gravar a ação que vamos usar no site (https://www.google.com/). Por exemplo, digitar python e apertar a tecla "enter"
# - Clicando em opções do teste (3 pontinhos), exportar o testeem um arquivo do tipo python (.py)
#
# - Copiei o arquivo original na célula abaixo e vou fazer algumas modificações

# %%
# Generated by Selenium IDE
# import pytest -> ELIMINAR OU COMENTAR O PYTEST - NÃO VAMOS UTILIZAR
import time
import json

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities

# %%
class TestSearchclick():
    def __init__ (self): # troquei para o método construtor
        self.driver = webdriver.Firefox(executable_path='/Users/michaellee/DSdegree/Aula20/geckodriver')
        self.vars = {}
  
    def teardown_method(self, method):
        self.driver.quit()
  
    def test_searchclick(self):
        self.driver.get("https://www.google.com/")
        self.driver.set_window_size(1659, 898)
        self.driver.find_element(By.NAME, "q").click()
        self.driver.find_element(By.NAME, "q").send_keys("python")
        self.driver.find_element(By.NAME, "q").send_keys(Keys.ENTER)

# %%
teste = TestSearchclick()

teste.test_searchclick()
