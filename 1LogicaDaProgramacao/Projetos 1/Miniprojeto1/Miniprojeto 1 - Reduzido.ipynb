# %%
data = [[66707599984, 'Conservador', (5100., 3500., 1400., 200.)],
 [55695397315, 'Conservador', (4900., 3000., 1400., 200.)],
 [63743886918, 'Conservador', (4700., 3200., 1300., 200.)],
 [55941368774, 'Conservador', (4600., 3100., 1500., 200.)],
 [75486280874, 'Conservador', (5000., 3600., 1400., 200.)],
 [53164949799, 'Conservador', (5400., 3900., 1700., 400.)],
 [39898704131, 'Conservador', (4600., 3400., 1400., 300.)],
 [53740901207, 'Conservador', (5000., 3400., 1500., 200.)],
 [51735950236, 'Conservador', (4400., 2900., 1400., 200.)],
 [47305108951, 'Conservador', (4900., 3100., 1500., 100.)],
 [63858864633, 'Conservador', (5400., 3700., 1500., 200.)],
 [53363167240, 'Conservador', (4800., 3400., 1600., 200.)],
 [72133754195, 'Conservador', (4800., 3000., 1400., 100.)],
 [52802483512, 'Conservador', (4300., 3000., 1100., 100.)],
 [57925287214, 'Conservador', (4800., 3400., 1900., 200.)],
 [74354632224, 'Conservador', (5000., 3000., 1600., 200.)],
 [64020216626, 'Conservador', (5000., 3400., 1600., 400.)],
 [78223722856, 'Conservador', (5200., 3500., 1500., 200.)],
 [58245228846, 'Conservador', (5200., 3400., 1400., 200.)],
 [74490686776, 'Conservador', (4700., 3200., 1600., 200.)],
 [48646824781, 'Conservador', (4800., 3100., 1600., 200.)],
 [77381458676, 'Conservador', (5400., 3400., 1500., 400.)],
 [41615431874, 'Conservador', (5200., 4100., 1500., 100.)],
 [52163844491, 'Conservador', (5500., 4200., 1400., 200.)],
 [70276304567, 'Conservador', (4900., 3100., 1500., 200.)],
 [69119828185, 'Conservador', (5000., 3200., 1200., 200.)],
 [65441690046, 'Conservador', (5500., 3500., 1300., 200.)],
 [56457227894, 'Conservador', (4900., 3600., 1400., 100.)],
 [46939428126, 'Conservador', (4400., 3000., 1300., 200.)],
 [60979942480, 'Conservador', (5100., 3400., 1500., 200.)],
 [41648583220, 'Conservador', (5000., 3500., 1300., 300.)],
 [50376331791, 'Conservador', (4500., 2300., 1300., 300.)],
 [67008801023, 'Conservador', (4400., 3200., 1300., 200.)],
 [72149193419, 'Conservador', (5000., 3500., 1600., 600.)],
 [62830733382, 'Conservador', (5100., 3800., 1900., 400.)],
 [56716675811, 'Conservador', (4800., 3000., 1400., 300.)],
 [61089667146, 'Conservador', (5100., 3800., 1600., 200.)],
 [47795509468, 'Conservador', (4600., 3200., 1400., 200.)],
 [60899885693, 'Conservador', (5300., 3700., 1500., 200.)],
 [53433670705, 'Conservador', (5000., 3300., 1400., 200.)],
 [54850120580, 'Moderado', (7000., 3200., 4700., 1400.)],
 [71457789994, 'Moderado', (6400., 3200., 4500., 1500.)],
 [67692777563, 'Moderado', (6900., 3100., 4900., 1500.)],
 [43133573182, 'Moderado', (5500., 2300., 4000., 1300.)],
 [55150612815, 'Moderado', (6500., 2800., 4600., 1500.)],
 [48211725243, 'Moderado', (5700., 2800., 4500., 1300.)],
 [76686463776, 'Moderado', (6300., 3300., 4700., 1600.)],
 [71971000560, 'Moderado', (4900., 2400., 3300., 1000.)],
 [40307235992, 'Moderado', (6600., 2900., 4600., 1300.)],
 [64703873108, '', (6000., 2200., 5000., 1500.)]]

# %% [markdown]
# ## Passo 1

# %%
# Definir uma valor para K
K = 5

# %% [markdown]
# ## Passo 2

# %% [markdown]
# Definir os K vizinhos mais próximos do ponto a ser classificado de acordo com uma função de distância.

# %%
# calcular a distância do ponto a todos os outros pontos

def distancia()
    i = 0
    for i in range(len(data)):
        list(data[i][2])

# %%
a = list(data[0][2])
b = list(no_class[0][2])

print(a)
print(b)
dist = []

for item1, item2 in zip(a, b):
    dist.append((item1 - item2) ** 2)
print(dist)
# Out:
# [5100.0, 3500.0, 1400.0, 200.0]
# [5800.0, 4000.0, 1200.0, 200.0]
# [490000.0, 250000.0, 40000.0, 0.0]

# %%
print(len(data))
print(len(no_class))
# Out:
# 120
# 30

# %%
i = 0
j = 0
dist = []

for i in range(len(data)):
    a = list(data[i][2])
    #print(a)
    
for j in range(len(no_class)):
    b = list(no_class[j][2])
    #print(b)    
       
    for item1, item2 in zip(a, b):
        dist.append((item1, item2))
print(dist)
# Out:
# [(5900.0, 5800.0), (3000.0, 4000.0), (5100.0, 1200.0), (1800.0, 200.0), (5900.0, 5700.0), (3000.0, 4400.0), (5100.0, 1500.0), (1800.0, 400.0), (5900.0, 5400.0), (3000.0, 3900.0), (5100.0, 1300.0), (1800.0, 400.0), (5900.0, 5100.0), (3000.0, 3500.0), (5100.0, 1400.0), (1800.0, 300.0), (5900.0, 5700.0), (3000.0, 3800.0), (5100.0, 1700.0), (1800.0, 300.0), (5900.0, 5100.0), (3000.0, 3800.0), (5100.0, 1500.0), (1800.0, 300.0), (5900.0, 5400.0), (3000.0, 3400.0), (5100.0, 1700.0), (1800.0, 200.0), (5900.0, 5100.0), (3000.0, 3700.0), (5100.0, 1500.0), (1800.0, 400.0), (5900.0, 4600.0), (3000.0, 3600.0), (5100.0, 1000.0), (1800.0, 200.0), (5900.0, 5100.0), (3000.0, 3300.0), (5100.0, 1700.0), (1800.0, 500.0), (5900.0, 5000.0), (3000.0, 2000.0), (5100.0, 3500.0), (1800.0, 1000.0), (5900.0, 5900.0), (3000.0, 3000.0), (5100.0, 4200.0), (1800.0, 1500.0), (5900.0, 6000.0), (3000.0, 2200.0), (5100.0, 4000.0), (1800.0, 1000.0), (5900.0, 6100.0), (3000.0, 2900.0), (5100.0, 4700.0), (1800.0, 1400.0), (5900.0, 5600.0), (3000.0, 2900.0), (5100.0, 3600.0), (1800.0, 1300.0), (5900.0, 6700.0), (3000.0, 3100.0), (5100.0, 4400.0), (1800.0, 1400.0), (5900.0, 5600.0), (3000.0, 3000.0), (5100.0, 4500.0), (1800.0, 1500.0), (5900.0, 5800.0), (3000.0, 2700.0), (5100.0, 4100.0), (1800.0, 1000.0), (5900.0, 6200.0), (3000.0, 2200.0), (5100.0, 4500.0), (1800.0, 1500.0), (5900.0, 5600.0), (3000.0, 2500.0), (5100.0, 3900.0), (1800.0, 1100.0), (5900.0, 6500.0), (3000.0, 3200.0), (5100.0, 5100.0), (1800.0, 2000.0), (5900.0, 6400.0), (3000.0, 2700.0), (5100.0, 5300.0), (1800.0, 1900.0), (5900.0, 6800.0), (3000.0, 3000.0), (5100.0, 5500.0), (1800.0, 2100.0), (5900.0, 5700.0), (3000.0, 2500.0), (5100.0, 5000.0), (1800.0, 2
# [6900.0, 3100.0, 5400.0, 2100.0]
# [6700.0, 3100.0, 5600.0, 2400.0]
# [6900.0, 3100.0, 5100.0, 2300.0]
# [5800.0, 2700.0, 5100.0, 1900.0]
# [6800.0, 3200.0, 5900.0, 2300.0]
# [6700.0, 3300.0, 5700.0, 2500.0]
# [6700.0, 3000.0, 5200.0, 2300.0]
# [6300.0, 2500.0, 5000.0, 1900.0]
# [6500.0, 3000.0, 5200.0, 2000.0]
# [6200.0, 3400.0, 5400.0, 2300.0]
# [5900.0, 3000.0, 5100.0, 1800.0]

# %%
data1 = [[61089667146, 'Conservador', (5100., 3800., 1600., 200.)],
 [47795509468, 'Conservador', (4600., 3200., 1400., 200.)],
 [60899885693, 'Conservador', (5300., 3700., 1500., 200.)],
 [49475220139, 'Moderado', (6200., 2900., 4300., 1300.)],
 [52245218531, 'Moderado', (5100., 2500., 3000., 1100.)],
 [50932926697, 'Moderado', (5700., 2800., 4100., 1300.)],
 [58529878272, 'Agressivo', (6500., 3000., 5200., 2000.)],
 [76005896622, 'Agressivo', (6200., 3400., 5400., 2300.)],
 [49212614633, 'Agressivo', (5900., 3000., 5100., 1800.)]]

no_class1 = [[45926320819, '', (5800., 4000., 1200., 200.)],            
 [68518284363, '', (5000., 2000., 3500., 1000.)],
 [64703873108, '', (6000., 2200., 5000., 1500.)]]

# %%
i = 0
j = 0


dist1 = []


for j in range(len(no_class1)):
    b = list(no_class1[j][2])

#    for i in range(len(data1)):
    a = list(data1[0][2])
    
    
    for item1, item2 in zip(a, b):
        dist1.append((item1, item2))
    print(dist1)

# %%
data2 = [[61089667146, 'Conservador', (5100., 3800., 1600., 200.)],
 [52245218531, 'Moderado', (5100., 2500., 3000., 1100.)],
 [49212614633, 'Agressivo', (5900., 3000., 5100., 1800.)]]

no_class2 = [[45926320819, '', (5800., 4000., 1200., 200.)],            
 [64703873108, '', (6000., 2200., 5000., 1500.)]]

# %%
# Segue a ordem da lista data2

i = 0
j = 0


dist2 = []

for i in range(len(data2)):
    a = list(data2[i][2])
    for j in range(len(no_class2)):
        b = list(no_class2[j][2])
        for item1, item2 in zip(a, b):   
            dist2.append((item2, item1))
print(dist2)
# Out:
# [(5800.0, 5100.0), (4000.0, 3800.0), (1200.0, 1600.0), (200.0, 200.0), (6000.0, 5100.0), (2200.0, 3800.0), (5000.0, 1600.0), (1500.0, 200.0), (5800.0, 5100.0), (4000.0, 2500.0), (1200.0, 3000.0), (200.0, 1100.0), (6000.0, 5100.0), (2200.0, 2500.0), (5000.0, 3000.0), (1500.0, 1100.0), (5800.0, 5900.0), (4000.0, 3000.0), (1200.0, 5100.0), (200.0, 1800.0), (6000.0, 5900.0), (2200.0, 3000.0), (5000.0, 5100.0), (1500.0, 1800.0)]

# %%
# Ordem certa -> Segue a ordem da lista no_class2

i = 0
j = 0


dist2 = []


for j in range(len(no_class2)):
    b = list(no_class2[j][2])
    for i in range(len(data2)):
        a = list(data2[i][2])
        for item1, item2 in zip(a, b):   
            dist2.append((item2, item1))
print(dist2)
# Out:
# [(5800.0, 5100.0), (4000.0, 3800.0), (1200.0, 1600.0), (200.0, 200.0), (5800.0, 5100.0), (4000.0, 2500.0), (1200.0, 3000.0), (200.0, 1100.0), (5800.0, 5900.0), (4000.0, 3000.0), (1200.0, 5100.0), (200.0, 1800.0), (6000.0, 5100.0), (2200.0, 3800.0), (5000.0, 1600.0), (1500.0, 200.0), (6000.0, 5100.0), (2200.0, 2500.0), (5000.0, 3000.0), (1500.0, 1100.0), (6000.0, 5900.0), (2200.0, 3000.0), (5000.0, 5100.0), (1500.0, 1800.0)]

# %%
i = 0
j = 0


dist2 = []


for j in range(len(no_class2)):
    b = list(no_class2[j][2])
    for i in range(len(data2)):
        a = list(data2[i][2])
        for item1, item2 in zip(a, b):   
            dist2.append(((item2 - item1) ** 2))


subdist2 = [dist2[n:n+4] for n in range(0, len(dist2), 4)]
print(subdist2)
# Out:
# [[490000.0, 40000.0, 160000.0, 0.0], [490000.0, 2250000.0, 3240000.0, 810000.0], [10000.0, 1000000.0, 15210000.0, 2560000.0], [810000.0, 2560000.0, 11560000.0, 1690000.0], [810000.0, 90000.0, 4000000.0, 160000.0], [10000.0, 640000.0, 10000.0, 90000.0]]

# %%
i = 0
j = 0
soma = 0

dist2 = []


for j in range(len(no_class2)):
    b = list(no_class2[j][2])
    for i in range(len(data2)):
        a = list(data2[i][2])
        for item1, item2 in zip(a, b):   
            dist2.append(((item2 - item1) ** 2))


subdist2 = [dist2[n:n+4] for n in range(0, len(dist2), 4)]

for i in range(len(subdist2)):
    quadrado = subdist2[i]
    for elemento in quadrado:
        soma += elemento
        print('Elemento: ' , elemento)
    print(soma)
# Out:
# Elemento:  490000.0
# Elemento:  40000.0
# Elemento:  160000.0
# Elemento:  0.0
# 690000.0
# Elemento:  490000.0
# Elemento:  2250000.0
# Elemento:  3240000.0
# Elemento:  810000.0
# 7480000.0
# Elemento:  10000.0
# Elemento:  1000000.0
# Elemento:  15210000.0
# Elemento:  2560000.0
# 26260000.0
# Elemento:  810000.0
# Elemento:  2560000.0
# Elemento:  11560000.0
# Elemento:  1690000.0
# 42880000.0
# Elemento:  810000.0
# Elemento:  90000.0
# Elemento:  4000000.0
# Elemento:  160000.0
# 47940000.0
# Elemento:  10000.0
# Elemento:  640000.0
# Elemento:  10000.0
# Elemento:  90000.0
# 48690000.0

# %%
# Função Distância

i = 0
j = 0
soma = 0

dist2 = []


for j in range(len(no_class2)):
    b = list(no_class2[j][2])
    for i in range(len(data2)):
        a = list(data2[i][2])
        for item1, item2 in zip(a, b):   
            dist2.append(((item2 - item1) ** 2))


subdist2 = [dist2[n:n+4] for n in range(0, len(dist2), 4)]

for i in range(len(subdist2)):
    quadrado = subdist2[i]
    distancia_final = sum(quadrado) ** (1 / 2)

    print(i, 'Elementos: ' , quadrado)
    print(i, 'Distância: ' , (sum(quadrado) ** (1 / 2)))
    print(distancia_final)
# Out:
# 0 Elementos:  [490000.0, 40000.0, 160000.0, 0.0]
# 0 Distância:  830.6623862918075
# 830.6623862918075
# 1 Elementos:  [490000.0, 2250000.0, 3240000.0, 810000.0]
# 1 Distância:  2605.7628441590764
# 2605.7628441590764
# 2 Elementos:  [10000.0, 1000000.0, 15210000.0, 2560000.0]
# 2 Distância:  4333.58973600409
# 4333.58973600409
# 3 Elementos:  [810000.0, 2560000.0, 11560000.0, 1690000.0]
# 3 Distância:  4076.763422127902
# 4076.763422127902
# 4 Elementos:  [810000.0, 90000.0, 4000000.0, 160000.0]
# 4 Distância:  2249.4443758403986
# 2249.4443758403986
# 5 Elementos:  [10000.0, 640000.0, 10000.0, 90000.0]
# 5 Distância:  866.0254037844386
# 866.0254037844386

# %%
i = 0
j = 0
soma = 0

dist2 = []


for j in range(len(no_class2)):
    b = list(no_class2[j][2])
    for i in range(len(data2)):
        a = list(data2[i][2])
        for item1, item2 in zip(a, b):   
            dist2.append(((item2 - item1) ** 2))


subdist2 = [dist2[n:n+4] for n in range(0, len(dist2), 4)]


lista_distancia_final = []

for i in range(len(subdist2)):
    quadrado = subdist2[i]
    distancia_final = sum(quadrado) ** (1 / 2)
    lista_distancia_final.append(distancia_final)
    
    print(i, 'Elementos: ' , quadrado)
    print(i, 'Distância: ' , (sum(quadrado) ** (1 / 2)))
    
print(lista_distancia_final)

multiplo = int(len(lista_distancia_final)/len(no_class2))
print(multiplo)


subdistancia_final = [lista_distancia_final[n:n+(multiplo)] for n in range(0, len(lista_distancia_final), multiplo)]

print(subdistancia_final)
# Out:
# 0 Elementos:  [490000.0, 40000.0, 160000.0, 0.0]
# 0 Distância:  830.6623862918075
# 1 Elementos:  [490000.0, 2250000.0, 3240000.0, 810000.0]
# 1 Distância:  2605.7628441590764
# 2 Elementos:  [10000.0, 1000000.0, 15210000.0, 2560000.0]
# 2 Distância:  4333.58973600409
# 3 Elementos:  [810000.0, 2560000.0, 11560000.0, 1690000.0]
# 3 Distância:  4076.763422127902
# 4 Elementos:  [810000.0, 90000.0, 4000000.0, 160000.0]
# 4 Distância:  2249.4443758403986
# 5 Elementos:  [10000.0, 640000.0, 10000.0, 90000.0]
# 5 Distância:  866.0254037844386
# [830.6623862918075, 2605.7628441590764, 4333.58973600409, 4076.763422127902, 2249.4443758403986, 866.0254037844386]
# 3
# [[830.6623862918075, 2605.7628441590764, 4333.58973600409], [4076.763422127902, 2249.4443758403986, 866.0254037844386]]

# %%
i = 0
j = 0
soma = 0

dist2 = []


for j in range(len(no_class2)):
    b = list(no_class2[j][2])
    for i in range(len(data2)):
        a = list(data2[i][2])
        for item1, item2 in zip(a, b):   
            dist2.append(((item2 - item1) ** 2))


subdist2 = [dist2[n:n+4] for n in range(0, len(dist2), 4)]


lista_distancia_final = []

for i in range(len(subdist2)):
    quadrado = subdist2[i]
    distancia_final = sum(quadrado) ** (1 / 2)
    lista_distancia_final.append(distancia_final)
    

multiplo = int(len(lista_distancia_final)/len(no_class2))

#função índice
lista_indice = []

for indice, distancia in enumerate(lista_distancia_final):
    print(indice, distancia)

#subdistancia_final = [lista_distancia_final[n:n+(multiplo)] for n in range(0, len(lista_distancia_final), multiplo)]

#print(subdistancia_final)
# Out:
# 0 830.6623862918075
# 1 2605.7628441590764
# 2 4333.58973600409
# 3 4076.763422127902
# 4 2249.4443758403986
# 5 866.0254037844386

# %%
multiplo
# Out:
# 3

# %%
i = 0
j = 0
soma = 0

dist2 = []


for j in range(len(no_class2)):
    b = list(no_class2[j][2])
    for i in range(len(data2)):
        a = list(data2[i][2])
        for item1, item2 in zip(a, b):   
            dist2.append(((item2 - item1) ** 2))


subdist2 = [dist2[n:n+4] for n in range(0, len(dist2), 4)]


lista_distancia_final = []

for i in range(len(subdist2)):
    quadrado = subdist2[i]
    distancia_final = sum(quadrado) ** (1 / 2)
    lista_distancia_final.append(distancia_final)
    

multiplo = int(len(lista_distancia_final)/len(no_class2))

#função índice
lista_indice = []
dicionario_distancia = {}


for indice, distancia in enumerate(lista_distancia_final):
# função dicionário
    dicionario_distancia[indice] = distancia

print(dicionario_distancia)
# Out:
# {0: 830.6623862918075, 1: 2605.7628441590764, 2: 4333.58973600409, 3: 4076.763422127902, 4: 2249.4443758403986, 5: 866.0254037844386}

# %%
data2 = [[61089667146, 'Conservador', (5100., 3800., 1600., 200.)],
 [52245218531, 'Moderado', (5100., 2500., 3000., 1100.)],
 [49212614633, 'Agressivo', (5900., 3000., 5100., 1800.)]]

no_class2 = [[45926320819, '', (5800., 4000., 1200., 200.)],            
 [64703873108, '', (6000., 2200., 5000., 1500.)]]

# %%
dicionario_data2 = {}

for indice1, perfil1 in enumerate(data2):
    dicionario_data2[indice1] = perfil1
print(dicionario_data2)
# Out:
# {0: [61089667146, 'Conservador', (5100.0, 3800.0, 1600.0, 200.0)], 1: [52245218531, 'Moderado', (5100.0, 2500.0, 3000.0, 1100.0)], 2: [49212614633, 'Agressivo', (5900.0, 3000.0, 5100.0, 1800.0)]}

# %%
dicionario_data2[0]
# Out:
# [61089667146, 'Conservador', (5100.0, 3800.0, 1600.0, 200.0)]

# %%
dicionario_data2[0][1]
# Out:
# 'Conservador'

# %%
dicionario_distancia.keys()
# Out:
# dict_keys([0, 1, 2, 3, 4, 5])

# %%
# Ordenar as distâncias

dicionario_ordenado = dict(sorted(dicionario_distancia.items(), key=lambda item: item[1]))

dicionario_ordenado
# Out:
# {0: 830.6623862918075,
#  5: 866.0254037844386,
#  4: 2249.4443758403986,
#  1: 2605.7628441590764,
#  3: 4076.763422127902,
#  2: 4333.58973600409}

# %%
dicionario_ordenado.keys()
# Out:
# dict_keys([0, 5, 4, 1, 3, 2])

# %%
# Seleção dos 3 primeiros K

menores_dist = list(dicionario_ordenado)[:3]

menores_dist
# Out:
# [0, 5, 4]

# %%
m = 0

for m in menores_dist:
    print(m)
#    print(dicionario_data2[m][1])
# Out:
# 0
# 5
# 4

# %% [markdown]
# ## Versão Reduzida

# %%
data2 = [[61089667146, 'Conservador', (5100., 3800., 1600., 200.)],
 [52245218531, 'Moderado', (5100., 2500., 3000., 1100.)],
 [49212614633, 'Agressivo', (5900., 3000., 5100., 1800.)]]

no_class2 = [[45926320819, '', (5800., 4000., 1200., 200.)],            
 [64703873108, '', (6000., 2200., 5000., 1500.)]]

# %%
# Função Distância

i = 0
dist2 = [] # Lista com distâncias



b = list(no_class2[0][2])
for i in range(len(data2)):
    a = list(data2[i][2])
    for item1, item2 in zip(a, b):   
        dist2.append(((item2 - item1) ** 2))


subdist2 = [dist2[n:n+4] for n in range(0, len(dist2), 4)]

for i in range(len(subdist2)):
    quadrado = subdist2[i]
    distancia_final = sum(quadrado) ** (1 / 2)


print('Distância', i , ":", (distancia_final))
# Out:
# Distância 2 : 4333.58973600409

# %%
# Função Distância Errada

i = 0
dist2 = [] # Lista com distâncias

b = list(no_class2[0][2])
for i in range(len(data2)):
    a = list(data2[i][2])
    for item1, item2 in zip(a, b):   
        dist2.append(((item2 - item1) ** 2))
        soma_quadrados = sum(dist2)
        distancia = soma_quadrados ** (1/2)

#for i in range(len(dist2)):
#    quadrado = dist2[i]
#    distancia_final = sum(quadrado) ** (1 / 2)
                     
# print(distancia_final)
        print(distancia)
        lista_distancia_final.append(distancia)
    
print(lista_distancia_final)
# Out:
# 700.0
# 728.0109889280518
# 830.6623862918075
# 830.6623862918075
# 1086.2780491200215
# 1852.0259177452135
# 2582.6343140289914
# 2734.9588662354686
# 2736.7864366808017
# 2913.760456866693
# 4868.264577855234
# 5124.451190127583
# [830.6623862918075, 2605.7628441590764, 4333.58973600409, 700.0, 728.0109889280518, 830.6623862918075, 830.6623862918075, 1086.2780491200215, 1852.0259177452135, 2582.6343140289914, 2734.9588662354686, 2736.7864366808017, 2913.760456866693, 4868.264577855234, 5124.451190127583, 700.0, 728.0109889280518, 830.6623862918075, 830.6623862918075, 1086.2780491200215, 1852.0259177452135, 2582.6343140289914, 2734.9588662354686, 2736.7864366808017, 2913.760456866693, 4868.264577855234, 5124.451190127583, 700.0, 728.0109889280518, 830.6623862918075, 830.6623862918075, 1086.2780491200215, 1852.0259177452135, 2582.6343140289914, 2734.9588662354686, 2736.7864366808017, 2913.760456866693, 4868.264577855234, 5124.451190127583]

# %%
# Colocando as distâncias de um ponto em uma lista

lista_distancia_final = []

for i in range(len(subdist2)):
    quadrado = subdist2[i]
    distancia_final = sum(quadrado) ** (1 / 2)
    lista_distancia_final.append(distancia_final)
    


dicionario_distancia = {}
#função índice
for indice, distancia in enumerate(lista_distancia_final):
# função dicionário
    dicionario_distancia[indice] = distancia

print('Dicionário das Distâncias: ' , dicionario_distancia)

# Ordenar as distâncias

dicionario_dist_ordenado = dict(sorted(dicionario_distancia.items(), key=lambda item: item[1]))

print('Dicionário das Distâncias em ordem: ' , dicionario_dist_ordenado)
# Out:
# Dicionário das Distâncias:  {0: 830.6623862918075, 1: 2605.7628441590764, 2: 4333.58973600409}
# Dicionário das Distâncias em ordem:  {0: 830.6623862918075, 1: 2605.7628441590764, 2: 4333.58973600409}

# %%
i = 0
dist = [] # Lista com distâncias


b = list(no_class2[j][2])
for i in range(len(data2)):
    a = list(data2[i][2])
    dist.append(sum([(x - y) ** 2 for x, y in zip(a, b)]) ** (1/2))
        
print(dist)
# Out:
# [830.6623862918075, 2605.7628441590764, 4333.58973600409]

# %% [markdown]
# # SOLUÇÃO

# %% [markdown]
# ### Função Distância

# %%
# Função Distância

def distancia(a, b, c):
    c.append(sum([(x - y) ** 2 for x, y in zip(a, b)]) ** (1/2))

# %%
# Teste Função Distância

distancia(data2[0][2], no_class2[0][2], dist)

print(dist)
# Out:
# [830.6623862918075]

# %%
i = 0
j = 0
dist = [] # Lista com distâncias

for j in range(len(no_class2)):
    for i in range(len(data2)):
        distancia(data2[i][2], no_class2[j][2], dist)
        
multiplo = int(len(dist)/len(no_class2))

subdist = [dist[n:n+multiplo] for n in range(0, len(dist), multiplo)]

print(multiplo)
print(subdist)
# Out:
# 3
# [[830.6623862918075, 2605.7628441590764, 4333.58973600409], [4076.763422127902, 2249.4443758403986, 866.0254037844386]]

# %% [markdown]
# ### Função Ordenar Dicionário

# %%
def ordem(d):
    dicionario_dist_ordenado = dict(sorted(d.items(), key=lambda item: item[1]))
    print('Dicionário das Distâncias em ordem: ' , dicionario_dist_ordenado)

# %%
i = 0
dist = [] # Lista com distâncias

for i in range(len(data2)):
    distancia(data2[i][2], no_class2[0][2], dist)

print(dist)
# Out:
# [830.6623862918075, 2605.7628441590764, 4333.58973600409]

# %% [markdown]
# ### Função Menores

# %%
def menores(e):
    menores_dist = list(e)[:3]
    print(menores_dist)

# %% [markdown]
# ## Miniprojeto Certo

# %%
i = 0
dist = [] # Lista com distâncias
dicionario_distancia = {} # Dicionário com distâncias

for i in range(len(data2)):
    distancia(data2[i][2], no_class2[0][2], dist)


for indice, numero in enumerate(dist):
    dicionario_distancia[indice] = numero

print('Dicionário das Distâncias: ' , dicionario_distancia)

# Ordenar as distâncias

dicionario_dist_ordenado = dict(sorted(dicionario_distancia.items(), key=lambda item: item[1]))

print('Dicionário das Distâncias em ordem: ' , dicionario_dist_ordenado)
# Out:
# Dicionário das Distâncias:  {0: 830.6623862918075, 1: 2605.7628441590764, 2: 4333.58973600409}
# Dicionário das Distâncias em ordem:  {0: 830.6623862918075, 1: 2605.7628441590764, 2: 4333.58973600409}

# %% [markdown]
# # Solução com Funções 'Distancia' e 'Ordem'

# %%
i = 0
dist = [] # Lista com distâncias
dicionario_distancia = {} # Dicionário com distâncias

for i in range(len(data2)):
    distancia(data2[i][2], no_class2[0][2], dist)


for indice, numero in enumerate(dist):
    dicionario_distancia[indice] = numero

print('Dicionário das Distâncias: ' , dicionario_distancia)

ordem(dicionario_distancia)
# Out:
# Dicionário das Distâncias:  {0: 830.6623862918075, 1: 2605.7628441590764, 2: 4333.58973600409}
# Dicionário das Distâncias em ordem:  {0: 830.6623862918075, 1: 2605.7628441590764, 2: 4333.58973600409}

# %% [markdown]
# ### Parte 1

# %%
dicionario_distancia = {}
#função índice
for indice, distancia in enumerate(dist):
    
# função dicionário
    dicionario_distancia[indice] = distancia

print('Dicionário das Distâncias: ' , dicionario_distancia)

# Ordenar as distâncias

dicionario_dist_ordenado = dict(sorted(dicionario_distancia.items(), key=lambda item: item[1]))

print('Dicionário das Distâncias em ordem: ' , dicionario_dist_ordenado)
# Out:
# Dicionário das Distâncias:  {0: 830.6623862918075, 1: 2605.7628441590764, 2: 4333.58973600409}
# Dicionário das Distâncias em ordem:  {0: 830.6623862918075, 1: 2605.7628441590764, 2: 4333.58973600409}

# %% [markdown]
# ### Parte 2

# %%
menores(dicionario_dist_ordenado)

# Achando os perfis mais pertos

m = 0

for m in menores_dist:
    print(dicionario_data2[m][1])
# Out:
# [0, 1, 2]
# Conservador
# Moderado
# Agressivo

# %%
# Seleção dos 3 primeiros K

menores_dist = list(dicionario_dist_ordenado)[:3]

menores_dist
# Out:
# [0, 1, 2]

# %%
# Achando os perfis mais pertos

m = 0

for m in menores_dist:
    print(dicionario_data2[m][1])
# Out:
# Conservador
# Moderado
# Agressivo
