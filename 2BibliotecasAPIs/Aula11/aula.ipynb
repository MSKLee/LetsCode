# %% [markdown]
# # Seaborn

# %% [markdown]
# ## Import das biblitecas necessárias

# %%
import seaborn as sns
sns.set_theme()

# %matplotlib inline

# %% [markdown]
# ## Problema

# %%
df_pinguins = sns.load_dataset('penguins')
df_pinguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
columns = {
    'species': 'espécie',
    'island': 'ilha',
    'bill_length_mm': 'comprimento_bico_mm',
    'bill_depth_mm': 'profundidade_bico_mm',
    'flipper_length_mm': 'comprimento_nadadeira_mm',
    'body_mass_g': 'massa_corpo_g',
    'sex': 'sexo'
    
}

df_pinguins.rename(columns=columns, inplace=True)
df_pinguins.head()
# Out:
#   espécie       ilha  comprimento_bico_mm  profundidade_bico_mm  \
# 0  Adelie  Torgersen                 39.1                  18.7
# 1  Adelie  Torgersen                 39.5                  17.4
# 2  Adelie  Torgersen                 40.3                  18.0
# 3  Adelie  Torgersen                  NaN                   NaN
# 4  Adelie  Torgersen                 36.7                  19.3
#
#    comprimento_nadadeira_mm  massa_corpo_g    sexo
# 0                     181.0         3750.0    Male
# 1                     186.0         3800.0  Female
# 2                     195.0         3250.0  Female
# 3                       NaN            NaN     NaN
# 4                     193.0         3450.0  Female

# %% [markdown]
# ## Visualização dos dados

# %% [markdown]
# ### distribuição

# %%
sns.distplot(df_pinguins['comprimento_nadadeira_mm']);
# Out:
# c:\users\luis uzai\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.displot(data=df_pinguins, x='comprimento_nadadeira_mm');

# %%
sns.displot(data=df_pinguins, x='comprimento_nadadeira_mm', stat='density');

# %%
sns.displot(data=df_pinguins, x='comprimento_nadadeira_mm', stat='density', kde=True);

# %%
sns.displot(data=df_pinguins, x='comprimento_nadadeira_mm', stat='probability', kde=True);

# %%
df_pinguins.head()
# Out:
#   espécie       ilha  comprimento_bico_mm  profundidade_bico_mm  \
# 0  Adelie  Torgersen                 39.1                  18.7
# 1  Adelie  Torgersen                 39.5                  17.4
# 2  Adelie  Torgersen                 40.3                  18.0
# 3  Adelie  Torgersen                  NaN                   NaN
# 4  Adelie  Torgersen                 36.7                  19.3
#
#    comprimento_nadadeira_mm  massa_corpo_g    sexo
# 0                     181.0         3750.0    Male
# 1                     186.0         3800.0  Female
# 2                     195.0         3250.0  Female
# 3                       NaN            NaN     NaN
# 4                     193.0         3450.0  Female

# %%
sns.displot(data=df_pinguins, x='comprimento_nadadeira_mm',
            hue='espécie',
            stat='density', kde=True);

# %%
sns.displot(data=df_pinguins, x='comprimento_nadadeira_mm',
            hue='espécie',
            col='sexo',
            stat='density', kde=True);

# %%
sns.displot(data=df_pinguins, x='comprimento_nadadeira_mm',
            hue='espécie',
            col='sexo', 
            kind='kde');

# %% [markdown]
# ### countplot

# %% [markdown]
# Nosso dataset é desbalanceado em relação ao sexo?

# %%
sns.countplot(data=df_pinguins, x='sexo');

# %% [markdown]
# Nosso dataset é balanceado em relação as ilhas?

# %%
sns.countplot(data=df_pinguins, x='ilha');
plt.title('Ilhas', loc='left');

# %% [markdown]
# Nas ilhas existem desbalanceamento em relação ao sexo?

# %%
sns.countplot(data=df_pinguins, x='ilha', hue='sexo');

# %% [markdown]
# Existe diferença entre as espécies nas ilhas?

# %%
sns.countplot(data=df_pinguins, x='ilha', hue='espécie');

# %%
sns.countplot(data=df_pinguins, x='espécie');

# %% [markdown]
# ### barplot

# %% [markdown]
# Será que o comprimento da nadadeira muda por espécie?

# %%
sns.barplot(x='comprimento_nadadeira_mm', y='espécie', data=df_pinguins);

# %% [markdown]
# Será que o comprimento da nadadeira muda por espécie em relação ao sexo?

# %%
sns.barplot(x='comprimento_nadadeira_mm', y='espécie', hue='sexo', data=df_pinguins);
plt.legend(loc='right');

# %% [markdown]
# ### boxplot

# %%
sns.boxplot(x='massa_corpo_g', data=df_pinguins, showmeans=True);

# %%
sns.boxplot(x='massa_corpo_g', y='espécie', data=df_pinguins, showmeans=True);

# %% [markdown]
# ### pointplot

# %%
sns.pointplot(x='espécie', y='comprimento_nadadeira_mm', data=df_pinguins);

# %% [markdown]
# ### gráfico de violino

# %%
sns.violinplot(x='espécie', y='comprimento_nadadeira_mm', data=df_pinguins);

# %%
sns.violinplot(x='espécie', y='comprimento_nadadeira_mm', hue='ilha', data=df_pinguins);

# %% [markdown]
# ### lmplot

# %%
sns.lmplot(x='comprimento_bico_mm', y='comprimento_nadadeira_mm', hue='espécie', data=df_pinguins);

# %% [markdown]
# ### heatmap

# %%
df_pinguins.corr()
# Out:
#                           comprimento_bico_mm  profundidade_bico_mm  \
# comprimento_bico_mm                  1.000000             -0.235053
# profundidade_bico_mm                -0.235053              1.000000
# comprimento_nadadeira_mm             0.656181             -0.583851
# massa_corpo_g                        0.595110             -0.471916
#
#                           comprimento_nadadeira_mm  massa_corpo_g
# comprimento_bico_mm                       0.656181       0.595110
# profundidade_bico_mm                     -0.583851      -0.471916
# comprimento_nadadeira_mm                  1.000000       0.871202
# massa_corpo_g                             0.871202       1.000000

# %%
sns.heatmap(df_pinguins.corr(), annot=True);
